# %%
text = """What is an API?
APIs are mechanisms that enable two software components to communicate with each other using a set of definitions and protocols. For example, the weather bureau’s software system contains daily weather data. The weather app on your phone “talks” to this system via APIs and shows you daily weather updates on your phone.

What does API stand for?
API stands for Application Programming Interface. In the context of APIs, the word Application refers to any software with a distinct function. Interface can be thought of as a contract of service between two applications. This contract defines how the two communicate with each other using requests and responses. Their API documentation contains information on how developers are to structure those requests and responses.

How do APIs work?
API architecture is usually explained in terms of client and server. The application sending the request is called the client, and the application sending the response is called the server. So in the weather example, the bureau’s weather database is the server, and the mobile app is the client. 

There are four different ways that APIs can work depending on when and why they were created.

SOAP APIs 
These APIs use Simple Object Access Protocol. Client and server exchange messages using XML. This is a less flexible API that was more popular in the past.

RPC APIs
These APIs are called Remote Procedure Calls. The client completes a function (or procedure) on the server, and the server sends the output back to the client.

Websocket APIs
Websocket API is another modern web API development that uses JSON objects to pass data. A WebSocket API supports two-way communication between client apps and the server. The server can send callback messages to connected clients, making it more efficient than REST API.

REST APIs
These are the most popular and flexible APIs found on the web today. The client sends requests to the server as data. The server uses this client input to start internal functions and returns output data back to the client. Let’s look at REST APIs in more detail below.

What are REST APIs?
REST stands for Representational State Transfer. REST defines a set of functions like GET, PUT, DELETE, etc. that clients can use to access server data. Clients and servers exchange data using HTTP.

The main feature of REST API is statelessness. Statelessness means that servers do not save client data between requests. Client requests to the server are similar to URLs you type in your browser to visit a website. The response from the server is plain data, without the typical graphical rendering of a web page.

Learn more about Rest API

What is web API?
A Web API or Web Service API is an application processing interface between a web server and web browser. All web services are APIs but not all APIs are web services. REST API is a special type of Web API that uses the standard architectural style explained above.

The different terms around APIs, like Java API or service APIs, exist because historically, APIs were created before the world wide web. Modern web APIs are REST APIs and the terms can be used interchangeably.

What are API integrations?
API integrations are software components that automatically update data between clients and servers. Some examples of API integrations are when automatic data sync to the cloud from your phone image gallery, or the time and date automatically sync on your laptop when you travel to another time zone. Enterprises can also use them to efficiently automate many system functions.

What are the benefits of REST APIs?
REST APIs offer four main benefits:

1. Integration 
APIs are used to integrate new applications with existing software systems. This increases development speed because each functionality doesn’t have to be written from scratch. You can use APIs to leverage existing code.

2. Innovation 
Entire industries can change with the arrival of a new app. Businesses need to respond quickly and support the rapid deployment of innovative services. They can do this by making changes at the API level without having to re-write the whole code.

3. Expansion
APIs present a unique opportunity for businesses to meet their clients’ needs across different platforms. For example, maps API allows map information integration via websites, Android,iOS, etc. Any business can give similar access to their internal databases by using free or paid APIs.

4. Ease of maintenance
The API acts as a gateway between two systems. Each system is obliged to make internal changes so that the API is not impacted. This way, any future code changes by one party do not impact the other party.

What are the different types of APIs?
APIs are classified both according to their architecture and scope of use. We have already explored the main types of API architectures so let’s take a look at the scope of use.

Private APIs
These are internal to an enterprise and only used for connecting systems and data within the business.

Public APIs 
These are open to the public and may be used by anyone. There may or not be some authorization and cost associated with these types of APIs.

Partner APIs 
These are only accessible by authorized external developers to aid business-to-business partnerships.

Composite APIs 
These combine two or more different APIs to address complex system requirements or behaviors. 

What is an API endpoint and why is it important?
API endpoints are the final touchpoints in the API communication system. These include server URLs, services, and other specific digital locations from where information is sent and received between systems. API endpoints are critical to enterprises for two main reasons: 

1. Security
API endpoints make the system vulnerable to attack. API monitoring is crucial for preventing misuse.

2. Performance
API endpoints, especially high traffic ones, can cause bottlenecks and affect system performance.

How to secure a REST API?
All APIs must be secured through proper authentication and monitoring. The two main ways to secure REST APIs include:

1. Authentication tokens 
These are used to authorize users to make the API call. Authentication tokens check that the users are who they claim to be and that they have access rights for that particular API call. For example, when you log in to your email server, your email client uses authentication tokens for secure access.

2. API keys 
API keys verify the program or application making the API call. They identify the application and ensure it has the access rights required to make the particular API call. API keys are not as secure as tokens but they allow API monitoring in order to gather data on usage. You may have noticed a long string of characters and numbers in your browser URL when you visit different websites. This string is an API key the website uses to make internal API calls.

How to create an API?
Due diligence and effort are required to build an API that other developers will want to work with and trust. These are the five steps required for high-quality API design:

1. Plan the API 
API specifications, like OpenAPI, provide the blueprint for your API design. It is better to think about different use cases in advance and ensure the API adheres to current API development standards.

2. Build the API
 API designers prototype APIs using boilerplate code. Once the prototype is tested, developers can customize it to internal specifications.

3. Test the API  
API testing is the same as software testing and must be done to prevent bugs and defects. API testing tools can be used to strength test the API against cyber attacks.

4. Document the API  
While APIs are self-explanatory, API documentation acts as a guide to improve usability. Well-documented APIs that offer a range of functions and use cases tend to be more popular in a service-oriented architecture.

5. Market the API 
Just as Amazon is an online marketplace for retail, API marketplaces exist for developers to buy and sell other APIs. Listing your API can allow you to monetize it.

What is API testing?
API testing strategies are similar to other software testing methodologies. The main focus is on validating server responses. API testing includes:

Making multiple requests to API endpoints for performance testing.
Writing unit tests for checking business logic and functional correctness.
Security testing by simulating system attacks. 
How to write API documentation?
Writing comprehensive API documentation is part of the API management process. API documentation can be auto-generated using tools or written manually. Some best practices include:

Writing explanations in simple, easy-to-read English. Documents generated by tools can become wordy and require editing.
Using code samples to explain functionality.
Maintaining the documentation so it is accurate and up-to-date.
Aiming the writing style at beginners
Covering all the problems the API can solve for the users.
How to use an API?
The steps to implement a new API include:

Obtaining an API key. This is done by creating a verified account with the API provider.
Set up an HTTP API client. This tool allows you to structure API requests easily using the API keys received.
If you don’t have an API client, you can try to structure the request yourself in your browser by referring to the API documentation.
Once you are comfortable with the new API syntax, you can start using it in your code.
Where can I find new APIs?
New web APIs can be found on API marketplaces and API directories. API marketplaces are open platforms where anyone can list an API for sale. API directories are controlled repositories regulated by the directory owner. Expert API designers may assess and test a new API before adding it to their directory.  

Some popular API websites include:

Rapid API – The largest global API market with over 10,000 public APIs and 1 million active developers on site. RapidAPI allows users to test APIs directly on the platform before committing to purchase.
Public APIs – The platform groups remote APIs into 40 niche categories, making it easier to browse and find the right one to meet your needs.
APIForThat and APIList – Both these websites have lists of 500+ web APIs, along with in-depth information on how to use them.    
What is an API gateway?
An API Gateway is an API management tool for enterprise clients that use a broad range of back-end services. API gateways typically handle common tasks like user authentication, statistics, and rate management that are applicable across all API calls.

Amazon API Gateway is a fully managed service that makes it easy for developers to create, publish, maintain, monitor, and secure APIs at any scale. It handles all the tasks involved in accepting and processing thousands of concurrent API calls, including traffic management, CORS support, authorization, and access control, throttling, monitoring, and API version management."""

# %%
text = text.replace('\n', '')

# %%
import spacy
from spacy.language import Language 
from string import punctuation

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# @Language.component("custom_segmentation")
# def custom_segmentation(doc):
#     for token in doc[:-1]:
#         if token.text == '\n':  # If newline character is found
#             doc[token.i + 1].is_sent_start = True
#     return doc

# nlp.add_pipe("custom_segmentation", before="parser")
doc = nlp(text)

# %%
tokens = [token.text.lower() for token in doc if not token.is_stop and not token.is_punct and token.text != '\n' and token.text != '\n\n']

# %%
tokens
# Out:
# ['api?apis',
#  'mechanisms',
#  'enable',
#  'software',
#  'components',
#  'communicate',
#  'set',
#  'definitions',
#  'protocols',
#  'example',
#  'weather',
#  'bureau',
#  'software',
#  'system',
#  'contains',
#  'daily',
#  'weather',
#  'data',
#  'weather',
#  'app',
#  'phone',
#  'talks',
#  'system',
#  'apis',
#  'shows',
#  'daily',
#  'weather',
#  'updates',
#  'phone',
#  'api',
#  'stand',
#  'for?api',
#  'stands',
#  'application',
#  'programming',
#  'interface',
#  'context',
#  'apis',
#  'word',
#  'application',
#  'refers',
#  'software',
#  'distinct',
#  'function',
#  'interface',
#  'thought',
#  'contract',
#  'service',
#  'applications',
#  'contract',
#  'defines',
#  'communicate',
#  'requests',
#  'responses',
#  'api',
#  'documentation',
#  'contains',
#  'information',
#  'developers',
#  'structure',
#  'requests',
#  'responses',
#  'apis',
#  'work?api',
#  'architecture',
#  'usually',
#  'explained',
#  'terms',
#  'client',
#  'server',
#  'application',
#  'sending',
#  'request',
#  'called',
#  'client',
#  'application',
#  'sending',
#  'response',
#  'called',
#  'server',
#  'weather',
#  'example',
#  'bureau',
#  'weather',
#  'database',
#  'server',
#  'mobile',
#  'app',
#  'client',
#  'different',
#  'ways',
#  'apis',
#  'work',
#  'depending',
#  'created',
#  'soap',
#  'apis',
#  'apis',
#  'use',
#  'simple',
#  'object',
#  'access',
#  'protocol',
#  'client',
#  'server',
#  'exchange',
#  'messages',
#  'xml',
#  'flexible',
#  'api',
#  'popular',
#  'past',
#  'rpc',
#  'apisthese',
#  'apis',
#  'called',
#  'remote',
#  'procedure',
#  'calls',
#  'client',
#  'completes',
#  'function',
#  'procedure',
#  'server',
#  'server',
#  'sends',
#  'output',
#  'client',
#  'websocket',
#  'apiswebsocket',
#  'api',
#  'modern',
#  'web',
#  'api',
#  'development',
#  'uses',
#  'json',
#  'objects',
#  'pass',
#  'data',
#  'websocket',
#  'api',
#  'supports',
#  'way',
#  'communication',
#  'client',
#  'apps',
#  'server',
#  'server',
#  'send',
#  'callback',
#  'messages',
#  'connected',
#  'clients',
#  'making',
#  'efficient',
#  'rest',
#  'api.rest',
#  'apisthese',
#  'popular',
#  'flexible',
#  'apis',
#  'found',
#  'web',
#  'today',
#  'client',
#  'sends',
#  'requests',
#  'server',
#  'data',
#  'server',
#  'uses',
#  'client',
#  'input',
#  'start',
#  'internal',
#  'functions',
#  'returns',
#  'output',
#  'data',
#  'client',
#  'let',
#  'look',
#  'rest',
#  'apis',
#  'detail',
#  'rest',
#  'apis?rest',
#  'stands',
#  'representational',
#  'state',
#  'transfer',
#  'rest',
#  'defines',
#  'set',
#  'functions',
#  'like',
#  'delete',
#  'etc',
#  'clients',
#  'use',
#  'access',
#  'server',
#  'data',
#  'clients',
#  'servers',
#  'exchange',
#  'data',
#  'http.the',
#  'main',
#  'feature',
#  'rest',
#  'api',
#  'statelessness',
#  'statelessness',
#  'means',
#  'servers',
#  'save',
#  'client',
#  'data',
#  'requests',
#  'client',
#  'requests',
#  'server',
#  'similar',
#  'urls',
#  'type',
#  'browser',
#  'visit',
#  'website',
#  'response',
#  'server',
#  'plain',
#  'data',
#  'typical',
#  'graphical',
#  'rendering',
#  'web',
#  'page',
#  'learn',
#  'rest',
#  'apiwhat',
#  'web',
#  'api?a',
#  'web',
#  'api',
#  'web',
#  'service',
#  'api',
#  'application',
#  'processing',
#  'interface',
#  'web',
#  'server',
#  'web',
#  'browser',
#  'web',
#  'services',
#  'apis',
#  'apis',
#  'web',
#  'services',
#  'rest',
#  'api',
#  'special',
#  'type',
#  'web',
#  'api',
#  'uses',
#  'standard',
#  'architectural',
#  'style',
#  'explained',
#  'different',
#  'terms',
#  'apis',
#  'like',
#  'java',
#  'api',
#  'service',
#  'apis',
#  'exist',
#  'historically',
#  'apis',
#  'created',
#  'world',
#  'wide',
#  'web',
#  'modern',
#  'web',
#  'apis',
#  'rest',
#  'apis',
#  'terms',
#  'interchangeably',
#  'api',
#  'integrations?api',
#  'integrations',
#  'software',
#  'components',
#  'automatically',
#  'update',
#  'data',
#  'clients',
#  'servers',
#  'examples',
#  'api',
#  'integrations',
#  'automatic',
#  'data',
#  'sync',
#  'cloud',
#  'phone',
#  'image',
#  'gallery',
#  'time',
#  'date',
#  'automatically',
#  'sync',
#  'laptop',
#  'travel',
#  'time',
#  'zone',
#  'enterprises',
#  'use',
#  'efficiently',
#  'automate',
#  'system',
#  'functions',
#  'benefits',
#  'rest',
#  'apis?rest',
#  'apis',
#  'offer',
#  'main',
#  'benefits:1',
#  'integration',
#  'apis',
#  'integrate',
#  'new',
#  'applications',
#  'existing',
#  'software',
#  'systems',
#  'increases',
#  'development',
#  'speed',
#  'functionality',
#  'written',
#  'scratch',
#  'use',
#  'apis',
#  'leverage',
#  'existing',
#  'code.2',
#  'innovation',
#  'entire',
#  'industries',
#  'change',
#  'arrival',
#  'new',
#  'app',
#  'businesses',
#  'need',
#  'respond',
#  'quickly',
#  'support',
#  'rapid',
#  'deployment',
#  'innovative',
#  'services',
#  'making',
#  'changes',
#  'api',
#  'level',
#  'having',
#  'write',
#  'code.3',
#  'expansionapis',
#  'present',
#  'unique',
#  'opportunity',
#  'businesses',
#  'meet',
#  'clients',
#  'needs',
#  'different',
#  'platforms',
#  'example',
#  'maps',
#  'api',
#  'allows',
#  'map',
#  'information',
#  'integration',
#  'websites',
#  'android',
#  'ios',
#  'etc',
#  'business',
#  'similar',
#  'access',
#  'internal',
#  'databases',
#  'free',
#  'paid',
#  'apis.4',
#  'ease',
#  'maintenancethe',
#  'api',
#  'acts',
#  'gateway',
#  'systems',
#  'system',
#  'obliged',
#  'internal',
#  'changes',
#  'api',
#  'impacted',
#  'way',
#  'future',
#  'code',
#  'changes',
#  'party',
#  'impact',
#  'party',
#  'different',
#  'types',
#  'apis?apis',
#  'classified',
#  'according',
#  'architecture',
#  'scope',
#  'use',
#  'explored',
#  'main',
#  'types',
#  'api',
#  'architectures',
#  'let',
#  'look',
#  'scope',
#  'use',
#  'private',
#  'apisthese',
#  'internal',
#  'enterprise',
#  'connecting',
#  'systems',
#  'data',
#  'business',
#  'public',
#  'apis',
#  'open',
#  'public',
#  'authorization',
#  'cost',
#  'associated',
#  'types',
#  'apis',
#  'partner',
#  'apis',
#  'accessible',
#  'authorized',
#  'external',
#  'developers',
#  'aid',
#  'business',
#  'business',
#  'partnerships',
#  'composite',
#  'apis',
#  'combine',
#  'different',
#  'apis',
#  'address',
#  'complex',
#  'system',
#  'requirements',
#  'behaviors',
#  'api',
#  'endpoint',
#  'important?api',
#  'endpoints',
#  'final',
#  'touchpoints',
#  'api',
#  'communication',
#  'system',
#  'include',
#  'server',
#  'urls',
#  'services',
#  'specific',
#  'digital',
#  'locations',
#  'information',
#  'sent',
#  'received',
#  'systems',
#  'api',
#  'endpoints',
#  'critical',
#  'enterprises',
#  'main',
#  'reasons',
#  '1',
#  'securityapi',
#  'endpoints',
#  'system',
#  'vulnerable',
#  'attack',
#  'api',
#  'monitoring',
#  'crucial',
#  'preventing',
#  'misuse.2',
#  'performanceapi',
#  'endpoints',
#  'especially',
#  'high',
#  'traffic',
#  'ones',
#  'cause',
#  'bottlenecks',
#  'affect',
#  'system',
#  'performance',
#  'secure',
#  'rest',
#  'api?all',
#  'apis',
#  'secured',
#  'proper',
#  'authentication',
#  'monitoring',
#  'main',
#  'ways',
#  'secure',
#  'rest',
#  'apis',
#  'include:1',
#  'authentication',
#  'tokens',
#  'authorize',
#  'users',
#  'api',
#  'authentication',
#  'tokens',
#  'check',
#  'users',
#  'claim',
#  'access',
#  'rights',
#  'particular',
#  'api',
#  'example',
#  'log',
#  'email',
#  'server',
#  'email',
#  'client',
#  'uses',
#  'authentication',
#  'tokens',
#  'secure',
#  'access.2',
#  'api',
#  'keys',
#  'api',
#  'keys',
#  'verify',
#  'program',
#  'application',
#  'making',
#  'api',
#  'identify',
#  'application',
#  'ensure',
#  'access',
#  'rights',
#  'required',
#  'particular',
#  'api',
#  'api',
#  'keys',
#  'secure',
#  'tokens',
#  'allow',
#  'api',
#  'monitoring',
#  'order',
#  'gather',
#  'data',
#  'usage',
#  'noticed',
#  'long',
#  'string',
#  'characters',
#  'numbers',
#  'browser',
#  'url',
#  'visit',
#  'different',
#  'websites',
#  'string',
#  'api',
#  'key',
#  'website',
#  'uses',
#  'internal',
#  'api',
#  'calls',
#  'create',
#  'api?due',
#  'diligence',
#  'effort',
#  'required',
#  'build',
#  'api',
#  'developers',
#  'want',
#  'work',
#  'trust',
#  'steps',
#  'required',
#  'high',
#  'quality',
#  'api',
#  'design:1',
#  'plan',
#  'api',
#  'api',
#  'specifications',
#  'like',
#  'openapi',
#  'provide',
#  'blueprint',
#  'api',
#  'design',
#  'better',
#  'think',
#  'different',
#  'use',
#  'cases',
#  'advance',
#  'ensure',
#  'api',
#  'adheres',
#  'current',
#  'api',
#  'development',
#  'standards.2',
#  'build',
#  'api',
#  'api',
#  'designers',
#  'prototype',
#  'apis',
#  'boilerplate',
#  'code',
#  'prototype',
#  'tested',
#  'developers',
#  'customize',
#  'internal',
#  'specifications.3',
#  'test',
#  'api',
#  ' ',
#  'api',
#  'testing',
#  'software',
#  'testing',
#  'prevent',
#  'bugs',
#  'defects',
#  'api',
#  'testing',
#  'tools',
#  'strength',
#  'test',
#  'api',
#  'cyber',
#  'attacks.4',
#  'document',
#  'api',
#  ' ',
#  'apis',
#  'self',
#  'explanatory',
#  'api',
#  'documentation',
#  'acts',
#  'guide',
#  'improve',
#  'usability',
#  'documented',
#  'apis',
#  'offer',
#  'range',
#  'functions',
#  'use',
#  'cases',
#  'tend',
#  'popular',
#  'service',
#  'oriented',
#  'architecture.5',
#  'market',
#  'api',
#  'amazon',
#  'online',
#  'marketplace',
#  'retail',
#  'api',
#  'marketplaces',
#  'exist',
#  'developers',
#  'buy',
#  'sell',
#  'apis',
#  'listing',
#  'api',
#  'allow',
#  'monetize',
#  'api',
#  'testing?api',
#  'testing',
#  'strategies',
#  'similar',
#  'software',
#  'testing',
#  'methodologies',
#  'main',
#  'focus',
#  'validating',
#  'server',
#  'responses',
#  'api',
#  'testing',
#  'includes',
#  'making',
#  'multiple',
#  'requests',
#  'api',
#  'endpoints',
#  'performance',
#  'testing',
#  'writing',
#  'unit',
#  'tests',
#  'checking',
#  'business',
#  'logic',
#  'functional',
#  'correctness',
#  'security',
#  'testing',
#  'simulating',
#  'system',
#  'attacks',
#  'write',
#  'api',
#  'documentation?writing',
#  'comprehensive',
#  'api',
#  'documentation',
#  'api',
#  'management',
#  'process',
#  'api',
#  'documentation',
#  'auto',
#  'generated',
#  'tools',
#  'written',
#  'manually',
#  'best',
#  'practices',
#  'include',
#  'writing',
#  'explanations',
#  'simple',
#  'easy',
#  'read',
#  'english',
#  'documents',
#  'generated',
#  'tools',
#  'wordy',
#  'require',
#  'editing',
#  'code',
#  'samples',
#  'explain',
#  'functionality',
#  'maintaining',
#  'documentation',
#  'accurate',
#  'date',
#  'aiming',
#  'writing',
#  'style',
#  'beginnerscovering',
#  'problems',
#  'api',
#  'solve',
#  'users',
#  'use',
#  'api?the',
#  'steps',
#  'implement',
#  'new',
#  'api',
#  'include',
#  'obtaining',
#  'api',
#  'key',
#  'creating',
#  'verified',
#  'account',
#  'api',
#  'provider',
#  'set',
#  'http',
#  'api',
#  'client',
#  'tool',
#  'allows',
#  'structure',
#  'api',
#  'requests',
#  'easily',
#  'api',
#  'keys',
#  'received',
#  'api',
#  'client',
#  'try',
#  'structure',
#  'request',
#  'browser',
#  'referring',
#  'api',
#  'documentation',
#  'comfortable',
#  'new',
#  'api',
#  'syntax',
#  'start',
#  'code',
#  'find',
#  'new',
#  'apis?new',
#  'web',
#  'apis',
#  'found',
#  'api',
#  'marketplaces',
#  'api',
#  'directories',
#  'api',
#  'marketplaces',
#  'open',
#  'platforms',
#  'list',
#  'api',
#  'sale',
#  'api',
#  'directories',
#  'controlled',
#  'repositories',
#  'regulated',
#  'directory',
#  'owner',
#  'expert',
#  'api',
#  'designers',
#  'assess',
#  'test',
#  'new',
#  'api',
#  'adding',
#  'directory',
#  ' ',
#  'popular',
#  'api',
#  'websites',
#  'include',
#  'rapid',
#  'api',
#  'largest',
#  'global',
#  'api',
#  'market',
#  '10,000',
#  'public',
#  'apis',
#  '1',
#  'million',
#  'active',
#  'developers',
#  'site',
#  'rapidapi',
#  'allows',
#  'users',
#  'test',
#  'apis',
#  'directly',
#  'platform',
#  'committing',
#  'purchase',
#  'public',
#  'apis',
#  'platform',
#  'groups',
#  'remote',
#  'apis',
#  '40',
#  'niche',
#  'categories',
#  'making',
#  'easier',
#  'browse',
#  'find',
#  'right',
#  'meet',
#  'needs',
#  'apiforthat',
#  'apilist',
#  'websites',
#  'lists',
#  '500',
#  '+',
#  'web',
#  'apis',
#  'depth',
#  'information',
#  'use',
#  '   ',
#  'api',
#  'gateway?an',
#  'api',
#  'gateway',
#  'api',
#  'management',
#  'tool',
#  'enterprise',
#  'clients',
#  'use',
#  'broad',
#  'range',
#  'end',
#  'services',
#  'api',
#  'gateways',
#  'typically',
#  'handle',
#  'common',
#  'tasks',
#  'like',
#  'user',
#  'authentication',
#  'statistics',
#  'rate',
#  'management',
#  'applicable',
#  'api',
#  'calls',
#  'amazon',
#  'api',
#  'gateway',
#  'fully',
#  'managed',
#  'service',
#  'makes',
#  'easy',
#  'developers',
#  'create',
#  'publish',
#  'maintain',
#  'monitor',
#  'secure',
#  'apis',
#  'scale',
#  'handles',
#  'tasks',
#  'involved',
#  'accepting',
#  'processing',
#  'thousands',
#  'concurrent',
#  'api',
#  'calls',
#  'including',
#  'traffic',
#  'management',
#  'cors',
#  'support',
#  ...]

# %%
from collections import Counter

# %%
word_freq = Counter(tokens)
word_freq
# Out:
# Counter({'api': 86,
#          'apis': 37,
#          'server': 17,
#          'client': 15,
#          'web': 15,
#          'data': 12,
#          'use': 11,
#          'rest': 11,
#          'system': 9,
#          'testing': 8,
#          'software': 7,
#          'application': 7,
#          'requests': 7,
#          'developers': 7,
#          'different': 7,
#          'weather': 6,
#          'documentation': 6,
#          'access': 6,
#          'clients': 6,
#          'internal': 6,
#          'main': 6,
#          'new': 6,
#          'service': 5,
#          'uses': 5,
#          'making': 5,
#          'services': 5,
#          'business': 5,
#          'endpoints': 5,
#          'secure': 5,
#          'authentication': 5,
#          'management': 5,
#          'example': 4,
#          'information': 4,
#          'popular': 4,
#          'calls': 4,
#          'functions': 4,
#          'like': 4,
#          'browser': 4,
#          'systems': 4,
#          'websites': 4,
#          'code': 4,
#          'public': 4,
#          'include': 4,
#          'monitoring': 4,
#          'tokens': 4,
#          'users': 4,
#          'keys': 4,
#          'test': 4,
#          'set': 3,
#          'app': 3,
#          'phone': 3,
#          'interface': 3,
#          'responses': 3,
#          'structure': 3,
#          'terms': 3,
#          'called': 3,
#          'apisthese': 3,
#          'development': 3,
#          'servers': 3,
#          'similar': 3,
#          'changes': 3,
#          'allows': 3,
#          'gateway': 3,
#          'types': 3,
#          'required': 3,
#          ' ': 3,
#          'tools': 3,
#          'marketplaces': 3,
#          'writing': 3,
#          'components': 2,
#          'communicate': 2,
#          'bureau': 2,
#          'contains': 2,
#          'daily': 2,
#          'stands': 2,
#          'function': 2,
#          'contract': 2,
#          'applications': 2,
#          'defines': 2,
#          'architecture': 2,
#          'explained': 2,
#          'sending': 2,
#          'request': 2,
#          'response': 2,
#          'ways': 2,
#          'work': 2,
#          'created': 2,
#          'simple': 2,
#          'exchange': 2,
#          'messages': 2,
#          'flexible': 2,
#          'remote': 2,
#          'procedure': 2,
#          'sends': 2,
#          'output': 2,
#          'websocket': 2,
#          'modern': 2,
#          'way': 2,
#          'communication': 2,
#          'found': 2,
#          'start': 2,
#          'let': 2,
#          'look': 2,
#          'apis?rest': 2,
#          'etc': 2,
#          'statelessness': 2,
#          'urls': 2,
#          'type': 2,
#          'visit': 2,
#          'website': 2,
#          'processing': 2,
#          'style': 2,
#          'exist': 2,
#          'integrations': 2,
#          'automatically': 2,
#          'sync': 2,
#          'time': 2,
#          'date': 2,
#          'enterprises': 2,
#          'offer': 2,
#          'integration': 2,
#          'existing': 2,
#          'functionality': 2,
#          'written': 2,
#          'businesses': 2,
#          'support': 2,
#          'rapid': 2,
#          'write': 2,
#          'meet': 2,
#          'needs': 2,
#          'platforms': 2,
#          'acts': 2,
#          'party': 2,
#          'scope': 2,
#          'enterprise': 2,
#          'open': 2,
#          'authorization': 2,
#          'received': 2,
#          '1': 2,
#          'high': 2,
#          'traffic': 2,
#          'performance': 2,
#          'rights': 2,
#          'particular': 2,
#          'email': 2,
#          'ensure': 2,
#          'allow': 2,
#          'string': 2,
#          'key': 2,
#          'create': 2,
#          'build': 2,
#          'steps': 2,
#          'cases': 2,
#          'designers': 2,
#          'prototype': 2,
#          'range': 2,
#          'market': 2,
#          'amazon': 2,
#          'generated': 2,
#          'easy': 2,
#          'tool': 2,
#          'find': 2,
#          'directories': 2,
#          'directory': 2,
#          'platform': 2,
#          'tasks': 2,
#          'api?apis': 1,
#          'mechanisms': 1,
#          'enable': 1,
#          'definitions': 1,
#          'protocols': 1,
#          'talks': 1,
#          'shows': 1,
#          'updates': 1,
#          'stand': 1,
#          'for?api': 1,
#          'programming': 1,
#          'context': 1,
#          'word': 1,
#          'refers': 1,
#          'distinct': 1,
#          'thought': 1,
#          'work?api': 1,
#          'usually': 1,
#          'database': 1,
#          'mobile': 1,
#          'depending': 1,
#          'soap': 1,
#          'object': 1,
#          'protocol': 1,
#          'xml': 1,
#          'past': 1,
#          'rpc': 1,
#          'completes': 1,
#          'apiswebsocket': 1,
#          'json': 1,
#          'objects': 1,
#          'pass': 1,
#          'supports': 1,
#          'apps': 1,
#          'send': 1,
#          'callback': 1,
#          'connected': 1,
#          'efficient': 1,
#          'api.rest': 1,
#          'today': 1,
#          'input': 1,
#          'returns': 1,
#          'detail': 1,
#          'representational': 1,
#          'state': 1,
#          'transfer': 1,
#          'delete': 1,
#          'http.the': 1,
#          'feature': 1,
#          'means': 1,
#          'save': 1,
#          'plain': 1,
#          'typical': 1,
#          'graphical': 1,
#          'rendering': 1,
#          'page': 1,
#          'learn': 1,
#          'apiwhat': 1,
#          'api?a': 1,
#          'special': 1,
#          'standard': 1,
#          'architectural': 1,
#          'java': 1,
#          'historically': 1,
#          'world': 1,
#          'wide': 1,
#          'interchangeably': 1,
#          'integrations?api': 1,
#          'update': 1,
#          'examples': 1,
#          'automatic': 1,
#          'cloud': 1,
#          'image': 1,
#          'gallery': 1,
#          'laptop': 1,
#          'travel': 1,
#          'zone': 1,
#          'efficiently': 1,
#          'automate': 1,
#          'benefits': 1,
#          'benefits:1': 1,
#          'integrate': 1,
#          'increases': 1,
#          'speed': 1,
#          'scratch': 1,
#          'leverage': 1,
#          'code.2': 1,
#          'innovation': 1,
#          'entire': 1,
#          'industries': 1,
#          'change': 1,
#          'arrival': 1,
#          'need': 1,
#          'respond': 1,
#          'quickly': 1,
#          'deployment': 1,
#          'innovative': 1,
#          'level': 1,
#          'having': 1,
#          'code.3': 1,
#          'expansionapis': 1,
#          'present': 1,
#          'unique': 1,
#          'opportunity': 1,
#          'maps': 1,
#          'map': 1,
#          'android': 1,
#          'ios': 1,
#          'databases': 1,
#          'free': 1,
#          'paid': 1,
#          'apis.4': 1,
#          'ease': 1,
#          'maintenancethe': 1,
#          'obliged': 1,
#          'impacted': 1,
#          'future': 1,
#          'impact': 1,
#          'apis?apis': 1,
#          'classified': 1,
#          'according': 1,
#          'explored': 1,
#          'architectures': 1,
#          'private': 1,
#          'connecting': 1,
#          'cost': 1,
#          'associated': 1,
#          'partner': 1,
#          'accessible': 1,
#          'authorized': 1,
#          'external': 1,
#          'aid': 1,
#          'partnerships': 1,
#          'composite': 1,
#          'combine': 1,
#          'address': 1,
#          'complex': 1,
#          'requirements': 1,
#          'behaviors': 1,
#          'endpoint': 1,
#          'important?api': 1,
#          'final': 1,
#          'touchpoints': 1,
#          'specific': 1,
#          'digital': 1,
#          'locations': 1,
#          'sent': 1,
#          'critical': 1,
#          'reasons': 1,
#          'securityapi': 1,
#          'vulnerable': 1,
#          'attack': 1,
#          'crucial': 1,
#          'preventing': 1,
#          'misuse.2': 1,
#          'performanceapi': 1,
#          'especially': 1,
#          'ones': 1,
#          'cause': 1,
#          'bottlenecks': 1,
#          'affect': 1,
#          'api?all': 1,
#          'secured': 1,
#          'proper': 1,
#          'include:1': 1,
#          'authorize': 1,
#          'check': 1,
#          'claim': 1,
#          'log': 1,
#          'access.2': 1,
#          'verify': 1,
#          'program': 1,
#          'identify': 1,
#          'order': 1,
#          'gather': 1,
#          'usage': 1,
#          'noticed': 1,
#          'long': 1,
#          'characters': 1,
#          'numbers': 1,
#          'url': 1,
#          'api?due': 1,
#          'diligence': 1,
#          'effort': 1,
#          'want': 1,
#          'trust': 1,
#          'quality': 1,
#          'design:1': 1,
#          'plan': 1,
#          'specifications': 1,
#          'openapi': 1,
#          'provide': 1,
#          'blueprint': 1,
#          'design': 1,
#          'better': 1,
#          'think': 1,
#          'advance': 1,
#          'adheres': 1,
#          'current': 1,
#          'standards.2': 1,
#          'boilerplate': 1,
#          'tested': 1,
#          'customize': 1,
#          'specifications.3': 1,
#          'prevent': 1,
#          'bugs': 1,
#          'defects': 1,
#          'strength': 1,
#          'cyber': 1,
#          'attacks.4': 1,
#          'document': 1,
#          'self': 1,
#          'explanatory': 1,
#          'guide': 1,
#          'improve': 1,
#          'usability': 1,
#          'documented': 1,
#          'tend': 1,
#          'oriented': 1,
#          'architecture.5': 1,
#          'online': 1,
#          'marketplace': 1,
#          'retail': 1,
#          'buy': 1,
#          'sell': 1,
#          'listing': 1,
#          'monetize': 1,
#          'testing?api': 1,
#          'strategies': 1,
#          'methodologies': 1,
#          'focus': 1,
#          'validating': 1,
#          'includes': 1,
#          'multiple': 1,
#          'unit': 1,
#          'tests': 1,
#          'checking': 1,
#          'logic': 1,
#          'functional': 1,
#          'correctness': 1,
#          'security': 1,
#          'simulating': 1,
#          'attacks': 1,
#          'documentation?writing': 1,
#          'comprehensive': 1,
#          'process': 1,
#          'auto': 1,
#          'manually': 1,
#          'best': 1,
#          'practices': 1,
#          'explanations': 1,
#          'read': 1,
#          'english': 1,
#          'documents': 1,
#          'wordy': 1,
#          'require': 1,
#          'editing': 1,
#          'samples': 1,
#          'explain': 1,
#          'maintaining': 1,
#          'accurate': 1,
#          'aiming': 1,
#          'beginnerscovering': 1,
#          'problems': 1,
#          'solve': 1,
#          'api?the': 1,
#          'implement': 1,
#          'obtaining': 1,
#          'creating': 1,
#          'verified': 1,
#          'account': 1,
#          'provider': 1,
#          'http': 1,
#          'easily': 1,
#          'try': 1,
#          'referring': 1,
#          'comfortable': 1,
#          'syntax': 1,
#          'apis?new': 1,
#          'list': 1,
#          'sale': 1,
#          'controlled': 1,
#          'repositories': 1,
#          'regulated': 1,
#          'owner': 1,
#          'expert': 1,
#          'assess': 1,
#          'adding': 1,
#          'largest': 1,
#          'global': 1,
#          '10,000': 1,
#          'million': 1,
#          'active': 1,
#          'site': 1,
#          'rapidapi': 1,
#          'directly': 1,
#          'committing': 1,
#          'purchase': 1,
#          'groups': 1,
#          '40': 1,
#          'niche': 1,
#          'categories': 1,
#          'easier': 1,
#          'browse': 1,
#          'right': 1,
#          'apiforthat': 1,
#          'apilist': 1,
#          'lists': 1,
#          '500': 1,
#          '+': 1,
#          'depth': 1,
#          '   ': 1,
#          'gateway?an': 1,
#          'broad': 1,
#          'end': 1,
#          'gateways': 1,
#          'typically': 1,
#          'handle': 1,
#          'common': 1,
#          'user': 1,
#          'statistics': 1,
#          'rate': 1,
#          'applicable': 1,
#          'fully': 1,
#          'managed': 1,
#          'makes': 1,
#          'publish': 1,
#          'maintain': 1,
#          'monitor': 1,
#          'scale': 1,
#          'handles': 1,
#          'involved': 1,
#          'accepting': 1,
#          'thousands': 1,
#          'concurrent': 1,
#          'including': 1,
#          'cors': 1,
#          'control': 1,
#          'throttling': 1,
#          'version': 1})

# %%
max_freq = max(word_freq.values())
for word in word_freq.keys():
    word_freq[word] /= max_freq

word_freq
# Out:
# Counter({'api': 1.0,
#          'apis': 0.43023255813953487,
#          'server': 0.19767441860465115,
#          'client': 0.1744186046511628,
#          'web': 0.1744186046511628,
#          'data': 0.13953488372093023,
#          'use': 0.12790697674418605,
#          'rest': 0.12790697674418605,
#          'system': 0.10465116279069768,
#          'testing': 0.09302325581395349,
#          'software': 0.08139534883720931,
#          'application': 0.08139534883720931,
#          'requests': 0.08139534883720931,
#          'developers': 0.08139534883720931,
#          'different': 0.08139534883720931,
#          'weather': 0.06976744186046512,
#          'documentation': 0.06976744186046512,
#          'access': 0.06976744186046512,
#          'clients': 0.06976744186046512,
#          'internal': 0.06976744186046512,
#          'main': 0.06976744186046512,
#          'new': 0.06976744186046512,
#          'service': 0.05813953488372093,
#          'uses': 0.05813953488372093,
#          'making': 0.05813953488372093,
#          'services': 0.05813953488372093,
#          'business': 0.05813953488372093,
#          'endpoints': 0.05813953488372093,
#          'secure': 0.05813953488372093,
#          'authentication': 0.05813953488372093,
#          'management': 0.05813953488372093,
#          'example': 0.046511627906976744,
#          'information': 0.046511627906976744,
#          'popular': 0.046511627906976744,
#          'calls': 0.046511627906976744,
#          'functions': 0.046511627906976744,
#          'like': 0.046511627906976744,
#          'browser': 0.046511627906976744,
#          'systems': 0.046511627906976744,
#          'websites': 0.046511627906976744,
#          'code': 0.046511627906976744,
#          'public': 0.046511627906976744,
#          'include': 0.046511627906976744,
#          'monitoring': 0.046511627906976744,
#          'tokens': 0.046511627906976744,
#          'users': 0.046511627906976744,
#          'keys': 0.046511627906976744,
#          'test': 0.046511627906976744,
#          'set': 0.03488372093023256,
#          'app': 0.03488372093023256,
#          'phone': 0.03488372093023256,
#          'interface': 0.03488372093023256,
#          'responses': 0.03488372093023256,
#          'structure': 0.03488372093023256,
#          'terms': 0.03488372093023256,
#          'called': 0.03488372093023256,
#          'apisthese': 0.03488372093023256,
#          'development': 0.03488372093023256,
#          'servers': 0.03488372093023256,
#          'similar': 0.03488372093023256,
#          'changes': 0.03488372093023256,
#          'allows': 0.03488372093023256,
#          'gateway': 0.03488372093023256,
#          'types': 0.03488372093023256,
#          'required': 0.03488372093023256,
#          ' ': 0.03488372093023256,
#          'tools': 0.03488372093023256,
#          'marketplaces': 0.03488372093023256,
#          'writing': 0.03488372093023256,
#          'components': 0.023255813953488372,
#          'communicate': 0.023255813953488372,
#          'bureau': 0.023255813953488372,
#          'contains': 0.023255813953488372,
#          'daily': 0.023255813953488372,
#          'stands': 0.023255813953488372,
#          'function': 0.023255813953488372,
#          'contract': 0.023255813953488372,
#          'applications': 0.023255813953488372,
#          'defines': 0.023255813953488372,
#          'architecture': 0.023255813953488372,
#          'explained': 0.023255813953488372,
#          'sending': 0.023255813953488372,
#          'request': 0.023255813953488372,
#          'response': 0.023255813953488372,
#          'ways': 0.023255813953488372,
#          'work': 0.023255813953488372,
#          'created': 0.023255813953488372,
#          'simple': 0.023255813953488372,
#          'exchange': 0.023255813953488372,
#          'messages': 0.023255813953488372,
#          'flexible': 0.023255813953488372,
#          'remote': 0.023255813953488372,
#          'procedure': 0.023255813953488372,
#          'sends': 0.023255813953488372,
#          'output': 0.023255813953488372,
#          'websocket': 0.023255813953488372,
#          'modern': 0.023255813953488372,
#          'way': 0.023255813953488372,
#          'communication': 0.023255813953488372,
#          'found': 0.023255813953488372,
#          'start': 0.023255813953488372,
#          'let': 0.023255813953488372,
#          'look': 0.023255813953488372,
#          'apis?rest': 0.023255813953488372,
#          'etc': 0.023255813953488372,
#          'statelessness': 0.023255813953488372,
#          'urls': 0.023255813953488372,
#          'type': 0.023255813953488372,
#          'visit': 0.023255813953488372,
#          'website': 0.023255813953488372,
#          'processing': 0.023255813953488372,
#          'style': 0.023255813953488372,
#          'exist': 0.023255813953488372,
#          'integrations': 0.023255813953488372,
#          'automatically': 0.023255813953488372,
#          'sync': 0.023255813953488372,
#          'time': 0.023255813953488372,
#          'date': 0.023255813953488372,
#          'enterprises': 0.023255813953488372,
#          'offer': 0.023255813953488372,
#          'integration': 0.023255813953488372,
#          'existing': 0.023255813953488372,
#          'functionality': 0.023255813953488372,
#          'written': 0.023255813953488372,
#          'businesses': 0.023255813953488372,
#          'support': 0.023255813953488372,
#          'rapid': 0.023255813953488372,
#          'write': 0.023255813953488372,
#          'meet': 0.023255813953488372,
#          'needs': 0.023255813953488372,
#          'platforms': 0.023255813953488372,
#          'acts': 0.023255813953488372,
#          'party': 0.023255813953488372,
#          'scope': 0.023255813953488372,
#          'enterprise': 0.023255813953488372,
#          'open': 0.023255813953488372,
#          'authorization': 0.023255813953488372,
#          'received': 0.023255813953488372,
#          '1': 0.023255813953488372,
#          'high': 0.023255813953488372,
#          'traffic': 0.023255813953488372,
#          'performance': 0.023255813953488372,
#          'rights': 0.023255813953488372,
#          'particular': 0.023255813953488372,
#          'email': 0.023255813953488372,
#          'ensure': 0.023255813953488372,
#          'allow': 0.023255813953488372,
#          'string': 0.023255813953488372,
#          'key': 0.023255813953488372,
#          'create': 0.023255813953488372,
#          'build': 0.023255813953488372,
#          'steps': 0.023255813953488372,
#          'cases': 0.023255813953488372,
#          'designers': 0.023255813953488372,
#          'prototype': 0.023255813953488372,
#          'range': 0.023255813953488372,
#          'market': 0.023255813953488372,
#          'amazon': 0.023255813953488372,
#          'generated': 0.023255813953488372,
#          'easy': 0.023255813953488372,
#          'tool': 0.023255813953488372,
#          'find': 0.023255813953488372,
#          'directories': 0.023255813953488372,
#          'directory': 0.023255813953488372,
#          'platform': 0.023255813953488372,
#          'tasks': 0.023255813953488372,
#          'api?apis': 0.011627906976744186,
#          'mechanisms': 0.011627906976744186,
#          'enable': 0.011627906976744186,
#          'definitions': 0.011627906976744186,
#          'protocols': 0.011627906976744186,
#          'talks': 0.011627906976744186,
#          'shows': 0.011627906976744186,
#          'updates': 0.011627906976744186,
#          'stand': 0.011627906976744186,
#          'for?api': 0.011627906976744186,
#          'programming': 0.011627906976744186,
#          'context': 0.011627906976744186,
#          'word': 0.011627906976744186,
#          'refers': 0.011627906976744186,
#          'distinct': 0.011627906976744186,
#          'thought': 0.011627906976744186,
#          'work?api': 0.011627906976744186,
#          'usually': 0.011627906976744186,
#          'database': 0.011627906976744186,
#          'mobile': 0.011627906976744186,
#          'depending': 0.011627906976744186,
#          'soap': 0.011627906976744186,
#          'object': 0.011627906976744186,
#          'protocol': 0.011627906976744186,
#          'xml': 0.011627906976744186,
#          'past': 0.011627906976744186,
#          'rpc': 0.011627906976744186,
#          'completes': 0.011627906976744186,
#          'apiswebsocket': 0.011627906976744186,
#          'json': 0.011627906976744186,
#          'objects': 0.011627906976744186,
#          'pass': 0.011627906976744186,
#          'supports': 0.011627906976744186,
#          'apps': 0.011627906976744186,
#          'send': 0.011627906976744186,
#          'callback': 0.011627906976744186,
#          'connected': 0.011627906976744186,
#          'efficient': 0.011627906976744186,
#          'api.rest': 0.011627906976744186,
#          'today': 0.011627906976744186,
#          'input': 0.011627906976744186,
#          'returns': 0.011627906976744186,
#          'detail': 0.011627906976744186,
#          'representational': 0.011627906976744186,
#          'state': 0.011627906976744186,
#          'transfer': 0.011627906976744186,
#          'delete': 0.011627906976744186,
#          'http.the': 0.011627906976744186,
#          'feature': 0.011627906976744186,
#          'means': 0.011627906976744186,
#          'save': 0.011627906976744186,
#          'plain': 0.011627906976744186,
#          'typical': 0.011627906976744186,
#          'graphical': 0.011627906976744186,
#          'rendering': 0.011627906976744186,
#          'page': 0.011627906976744186,
#          'learn': 0.011627906976744186,
#          'apiwhat': 0.011627906976744186,
#          'api?a': 0.011627906976744186,
#          'special': 0.011627906976744186,
#          'standard': 0.011627906976744186,
#          'architectural': 0.011627906976744186,
#          'java': 0.011627906976744186,
#          'historically': 0.011627906976744186,
#          'world': 0.011627906976744186,
#          'wide': 0.011627906976744186,
#          'interchangeably': 0.011627906976744186,
#          'integrations?api': 0.011627906976744186,
#          'update': 0.011627906976744186,
#          'examples': 0.011627906976744186,
#          'automatic': 0.011627906976744186,
#          'cloud': 0.011627906976744186,
#          'image': 0.011627906976744186,
#          'gallery': 0.011627906976744186,
#          'laptop': 0.011627906976744186,
#          'travel': 0.011627906976744186,
#          'zone': 0.011627906976744186,
#          'efficiently': 0.011627906976744186,
#          'automate': 0.011627906976744186,
#          'benefits': 0.011627906976744186,
#          'benefits:1': 0.011627906976744186,
#          'integrate': 0.011627906976744186,
#          'increases': 0.011627906976744186,
#          'speed': 0.011627906976744186,
#          'scratch': 0.011627906976744186,
#          'leverage': 0.011627906976744186,
#          'code.2': 0.011627906976744186,
#          'innovation': 0.011627906976744186,
#          'entire': 0.011627906976744186,
#          'industries': 0.011627906976744186,
#          'change': 0.011627906976744186,
#          'arrival': 0.011627906976744186,
#          'need': 0.011627906976744186,
#          'respond': 0.011627906976744186,
#          'quickly': 0.011627906976744186,
#          'deployment': 0.011627906976744186,
#          'innovative': 0.011627906976744186,
#          'level': 0.011627906976744186,
#          'having': 0.011627906976744186,
#          'code.3': 0.011627906976744186,
#          'expansionapis': 0.011627906976744186,
#          'present': 0.011627906976744186,
#          'unique': 0.011627906976744186,
#          'opportunity': 0.011627906976744186,
#          'maps': 0.011627906976744186,
#          'map': 0.011627906976744186,
#          'android': 0.011627906976744186,
#          'ios': 0.011627906976744186,
#          'databases': 0.011627906976744186,
#          'free': 0.011627906976744186,
#          'paid': 0.011627906976744186,
#          'apis.4': 0.011627906976744186,
#          'ease': 0.011627906976744186,
#          'maintenancethe': 0.011627906976744186,
#          'obliged': 0.011627906976744186,
#          'impacted': 0.011627906976744186,
#          'future': 0.011627906976744186,
#          'impact': 0.011627906976744186,
#          'apis?apis': 0.011627906976744186,
#          'classified': 0.011627906976744186,
#          'according': 0.011627906976744186,
#          'explored': 0.011627906976744186,
#          'architectures': 0.011627906976744186,
#          'private': 0.011627906976744186,
#          'connecting': 0.011627906976744186,
#          'cost': 0.011627906976744186,
#          'associated': 0.011627906976744186,
#          'partner': 0.011627906976744186,
#          'accessible': 0.011627906976744186,
#          'authorized': 0.011627906976744186,
#          'external': 0.011627906976744186,
#          'aid': 0.011627906976744186,
#          'partnerships': 0.011627906976744186,
#          'composite': 0.011627906976744186,
#          'combine': 0.011627906976744186,
#          'address': 0.011627906976744186,
#          'complex': 0.011627906976744186,
#          'requirements': 0.011627906976744186,
#          'behaviors': 0.011627906976744186,
#          'endpoint': 0.011627906976744186,
#          'important?api': 0.011627906976744186,
#          'final': 0.011627906976744186,
#          'touchpoints': 0.011627906976744186,
#          'specific': 0.011627906976744186,
#          'digital': 0.011627906976744186,
#          'locations': 0.011627906976744186,
#          'sent': 0.011627906976744186,
#          'critical': 0.011627906976744186,
#          'reasons': 0.011627906976744186,
#          'securityapi': 0.011627906976744186,
#          'vulnerable': 0.011627906976744186,
#          'attack': 0.011627906976744186,
#          'crucial': 0.011627906976744186,
#          'preventing': 0.011627906976744186,
#          'misuse.2': 0.011627906976744186,
#          'performanceapi': 0.011627906976744186,
#          'especially': 0.011627906976744186,
#          'ones': 0.011627906976744186,
#          'cause': 0.011627906976744186,
#          'bottlenecks': 0.011627906976744186,
#          'affect': 0.011627906976744186,
#          'api?all': 0.011627906976744186,
#          'secured': 0.011627906976744186,
#          'proper': 0.011627906976744186,
#          'include:1': 0.011627906976744186,
#          'authorize': 0.011627906976744186,
#          'check': 0.011627906976744186,
#          'claim': 0.011627906976744186,
#          'log': 0.011627906976744186,
#          'access.2': 0.011627906976744186,
#          'verify': 0.011627906976744186,
#          'program': 0.011627906976744186,
#          'identify': 0.011627906976744186,
#          'order': 0.011627906976744186,
#          'gather': 0.011627906976744186,
#          'usage': 0.011627906976744186,
#          'noticed': 0.011627906976744186,
#          'long': 0.011627906976744186,
#          'characters': 0.011627906976744186,
#          'numbers': 0.011627906976744186,
#          'url': 0.011627906976744186,
#          'api?due': 0.011627906976744186,
#          'diligence': 0.011627906976744186,
#          'effort': 0.011627906976744186,
#          'want': 0.011627906976744186,
#          'trust': 0.011627906976744186,
#          'quality': 0.011627906976744186,
#          'design:1': 0.011627906976744186,
#          'plan': 0.011627906976744186,
#          'specifications': 0.011627906976744186,
#          'openapi': 0.011627906976744186,
#          'provide': 0.011627906976744186,
#          'blueprint': 0.011627906976744186,
#          'design': 0.011627906976744186,
#          'better': 0.011627906976744186,
#          'think': 0.011627906976744186,
#          'advance': 0.011627906976744186,
#          'adheres': 0.011627906976744186,
#          'current': 0.011627906976744186,
#          'standards.2': 0.011627906976744186,
#          'boilerplate': 0.011627906976744186,
#          'tested': 0.011627906976744186,
#          'customize': 0.011627906976744186,
#          'specifications.3': 0.011627906976744186,
#          'prevent': 0.011627906976744186,
#          'bugs': 0.011627906976744186,
#          'defects': 0.011627906976744186,
#          'strength': 0.011627906976744186,
#          'cyber': 0.011627906976744186,
#          'attacks.4': 0.011627906976744186,
#          'document': 0.011627906976744186,
#          'self': 0.011627906976744186,
#          'explanatory': 0.011627906976744186,
#          'guide': 0.011627906976744186,
#          'improve': 0.011627906976744186,
#          'usability': 0.011627906976744186,
#          'documented': 0.011627906976744186,
#          'tend': 0.011627906976744186,
#          'oriented': 0.011627906976744186,
#          'architecture.5': 0.011627906976744186,
#          'online': 0.011627906976744186,
#          'marketplace': 0.011627906976744186,
#          'retail': 0.011627906976744186,
#          'buy': 0.011627906976744186,
#          'sell': 0.011627906976744186,
#          'listing': 0.011627906976744186,
#          'monetize': 0.011627906976744186,
#          'testing?api': 0.011627906976744186,
#          'strategies': 0.011627906976744186,
#          'methodologies': 0.011627906976744186,
#          'focus': 0.011627906976744186,
#          'validating': 0.011627906976744186,
#          'includes': 0.011627906976744186,
#          'multiple': 0.011627906976744186,
#          'unit': 0.011627906976744186,
#          'tests': 0.011627906976744186,
#          'checking': 0.011627906976744186,
#          'logic': 0.011627906976744186,
#          'functional': 0.011627906976744186,
#          'correctness': 0.011627906976744186,
#          'security': 0.011627906976744186,
#          'simulating': 0.011627906976744186,
#          'attacks': 0.011627906976744186,
#          'documentation?writing': 0.011627906976744186,
#          'comprehensive': 0.011627906976744186,
#          'process': 0.011627906976744186,
#          'auto': 0.011627906976744186,
#          'manually': 0.011627906976744186,
#          'best': 0.011627906976744186,
#          'practices': 0.011627906976744186,
#          'explanations': 0.011627906976744186,
#          'read': 0.011627906976744186,
#          'english': 0.011627906976744186,
#          'documents': 0.011627906976744186,
#          'wordy': 0.011627906976744186,
#          'require': 0.011627906976744186,
#          'editing': 0.011627906976744186,
#          'samples': 0.011627906976744186,
#          'explain': 0.011627906976744186,
#          'maintaining': 0.011627906976744186,
#          'accurate': 0.011627906976744186,
#          'aiming': 0.011627906976744186,
#          'beginnerscovering': 0.011627906976744186,
#          'problems': 0.011627906976744186,
#          'solve': 0.011627906976744186,
#          'api?the': 0.011627906976744186,
#          'implement': 0.011627906976744186,
#          'obtaining': 0.011627906976744186,
#          'creating': 0.011627906976744186,
#          'verified': 0.011627906976744186,
#          'account': 0.011627906976744186,
#          'provider': 0.011627906976744186,
#          'http': 0.011627906976744186,
#          'easily': 0.011627906976744186,
#          'try': 0.011627906976744186,
#          'referring': 0.011627906976744186,
#          'comfortable': 0.011627906976744186,
#          'syntax': 0.011627906976744186,
#          'apis?new': 0.011627906976744186,
#          'list': 0.011627906976744186,
#          'sale': 0.011627906976744186,
#          'controlled': 0.011627906976744186,
#          'repositories': 0.011627906976744186,
#          'regulated': 0.011627906976744186,
#          'owner': 0.011627906976744186,
#          'expert': 0.011627906976744186,
#          'assess': 0.011627906976744186,
#          'adding': 0.011627906976744186,
#          'largest': 0.011627906976744186,
#          'global': 0.011627906976744186,
#          '10,000': 0.011627906976744186,
#          'million': 0.011627906976744186,
#          'active': 0.011627906976744186,
#          'site': 0.011627906976744186,
#          'rapidapi': 0.011627906976744186,
#          'directly': 0.011627906976744186,
#          'committing': 0.011627906976744186,
#          'purchase': 0.011627906976744186,
#          'groups': 0.011627906976744186,
#          '40': 0.011627906976744186,
#          'niche': 0.011627906976744186,
#          'categories': 0.011627906976744186,
#          'easier': 0.011627906976744186,
#          'browse': 0.011627906976744186,
#          'right': 0.011627906976744186,
#          'apiforthat': 0.011627906976744186,
#          'apilist': 0.011627906976744186,
#          'lists': 0.011627906976744186,
#          '500': 0.011627906976744186,
#          '+': 0.011627906976744186,
#          'depth': 0.011627906976744186,
#          '   ': 0.011627906976744186,
#          'gateway?an': 0.011627906976744186,
#          'broad': 0.011627906976744186,
#          'end': 0.011627906976744186,
#          'gateways': 0.011627906976744186,
#          'typically': 0.011627906976744186,
#          'handle': 0.011627906976744186,
#          'common': 0.011627906976744186,
#          'user': 0.011627906976744186,
#          'statistics': 0.011627906976744186,
#          'rate': 0.011627906976744186,
#          'applicable': 0.011627906976744186,
#          'fully': 0.011627906976744186,
#          'managed': 0.011627906976744186,
#          'makes': 0.011627906976744186,
#          'publish': 0.011627906976744186,
#          'maintain': 0.011627906976744186,
#          'monitor': 0.011627906976744186,
#          'scale': 0.011627906976744186,
#          'handles': 0.011627906976744186,
#          'involved': 0.011627906976744186,
#          'accepting': 0.011627906976744186,
#          'thousands': 0.011627906976744186,
#          'concurrent': 0.011627906976744186,
#          'including': 0.011627906976744186,
#          'cors': 0.011627906976744186,
#          'control': 0.011627906976744186,
#          'throttling': 0.011627906976744186,
#          'version': 0.011627906976744186})

# %%
sent_token = [sent.text for sent in doc.sents]
sent_token
# Out:
# ['What is an API?APIs are mechanisms that enable two software components to communicate with each other using a set of definitions and protocols.',
#  'For example, the weather bureau’s software system contains daily weather data.',
#  'The weather app on your phone “talks” to this system via APIs and shows you daily weather updates on your phone.',
#  'What does API stand for?API stands for Application Programming Interface.',
#  'In the context of APIs, the word Application refers to any software with a distinct function.',
#  'Interface can be thought of as a contract of service between two applications.',
#  'This contract defines how the two communicate with each other using requests and responses.',
#  'Their API documentation contains information on how developers are to structure those requests and responses.',
#  'How do APIs work?API architecture is usually explained in terms of client and server.',
#  'The application sending the request is called the client, and the application sending the response is called the server.',
#  'So in the weather example, the bureau’s weather database is the server, and the mobile app is the client.',
#  'There are four different ways that APIs can work depending on when and why they were created.',
#  'SOAP APIs These APIs use Simple Object Access Protocol.',
#  'Client and server exchange messages using XML.',
#  'This is a less flexible API that was more popular in the past.',
#  'RPC APIsThese APIs are called Remote Procedure Calls.',
#  'The client completes a function (or procedure) on the server, and the server sends the output back to the client.',
#  'Websocket APIsWebsocket API is another modern web API development that uses JSON objects to pass data.',
#  'A WebSocket API supports two-way communication between client apps and the server.',
#  'The server can send callback messages to connected clients, making it more efficient than REST API.REST APIsThese are the most popular and flexible APIs found on the web today.',
#  'The client sends requests to the server as data.',
#  'The server uses this client input to start internal functions and returns output data back to the client.',
#  'Let’s look at REST APIs in more detail below.',
#  'What are REST APIs?REST stands for Representational State Transfer.',
#  'REST defines a set of functions like GET, PUT, DELETE, etc. that clients can use to access server data.',
#  'Clients and servers exchange data using HTTP.The main feature of REST API is statelessness.',
#  'Statelessness means that servers do not save client data between requests.',
#  'Client requests to the server are similar to URLs you type in your browser to visit a website.',
#  'The response from the server is plain data, without the typical graphical rendering of a web page.',
#  'Learn more about Rest APIWhat is web API?A Web API or Web Service API is an application processing interface between a web server and web browser.',
#  'All web services are APIs but not all APIs are web services.',
#  'REST API is a special type of Web API that uses the standard architectural style explained above.',
#  'The different terms around APIs, like Java API or service APIs, exist because historically, APIs were created before the world wide web.',
#  'Modern web APIs are REST APIs and the terms can be used interchangeably.',
#  'What are API integrations?API integrations are software components that automatically update data between clients and servers.',
#  'Some examples of API integrations are when automatic data sync to the cloud from your phone image gallery, or the time and date automatically sync on your laptop when you travel to another time zone.',
#  'Enterprises can also use them to efficiently automate many system functions.',
#  'What are the benefits of REST APIs?REST APIs offer four main benefits:1.',
#  'Integration APIs are used to integrate new applications with existing software systems.',
#  'This increases development speed because each functionality doesn’t have to be written from scratch.',
#  'You can use APIs to leverage existing code.2.',
#  'Innovation Entire industries can change with the arrival of a new app.',
#  'Businesses need to respond quickly and support the rapid deployment of innovative services.',
#  'They can do this by making changes at the API level without having to re-write the whole code.3.',
#  'ExpansionAPIs present a unique opportunity for businesses to meet their clients’ needs across different platforms.',
#  'For example, maps API allows map information integration via websites, Android,iOS, etc.',
#  'Any business can give similar access to their internal databases by using free or paid APIs.4.',
#  'Ease of maintenanceThe API acts as a gateway between two systems.',
#  'Each system is obliged to make internal changes so that the API is not impacted.',
#  'This way, any future code changes by one party do not impact the other party.',
#  'What are the different types of APIs?APIs are classified both according to their architecture and scope of use.',
#  'We have already explored the main types of API architectures so let’s take a look at the scope of use.',
#  'Private APIsThese are internal to an enterprise and only used for connecting systems and data within the business.',
#  'Public APIs These are open to the public and may be used by anyone.',
#  'There may or not be some authorization and cost associated with these types of APIs.',
#  'Partner APIs These are only accessible by authorized external developers to aid business-to-business partnerships.',
#  'Composite APIs These combine two or more different APIs to address complex system requirements or behaviors.',
#  'What is an API endpoint and why is it important?API endpoints are the final touchpoints in the API communication system.',
#  'These include server URLs, services, and other specific digital locations from where information is sent and received between systems.',
#  'API endpoints are critical to enterprises for two main reasons: 1. SecurityAPI endpoints make the system vulnerable to attack.',
#  'API monitoring is crucial for preventing misuse.2.',
#  'PerformanceAPI endpoints, especially high traffic ones, can cause bottlenecks and affect system performance.',
#  'How to secure a REST API?All APIs must be secured through proper authentication and monitoring.',
#  'The two main ways to secure REST APIs include:1.',
#  'Authentication tokens These are used to authorize users to make the API call.',
#  'Authentication tokens check that the users are who they claim to be and that they have access rights for that particular API call.',
#  'For example, when you log in to your email server, your email client uses authentication tokens for secure access.2.',
#  'API keys API keys verify the program or application making the API call.',
#  'They identify the application and ensure it has the access rights required to make the particular API call.',
#  'API keys are not as secure as tokens but they allow API monitoring in order to gather data on usage.',
#  'You may have noticed a long string of characters and numbers in your browser URL when you visit different websites.',
#  'This string is an API key the website uses to make internal API calls.',
#  'How to create an API?Due diligence and effort are required to build an API that other developers will want to work with and trust.',
#  'These are the five steps required for high-quality API design:1.',
#  'Plan the API API specifications, like OpenAPI, provide the blueprint for your API design.',
#  'It is better to think about different use cases in advance and ensure the API adheres to current API development standards.2.',
#  'Build the API API designers prototype APIs using boilerplate code.',
#  'Once the prototype is tested, developers can customize it to internal specifications.3.',
#  'Test the API  API testing is the same as software testing and must be done to prevent bugs and defects.',
#  'API testing tools can be used to strength test the API against cyber attacks.4.',
#  'Document the API  While APIs are self-explanatory, API documentation acts as a guide to improve usability.',
#  'Well-documented APIs that offer a range of functions and use cases tend to be more popular in a service-oriented architecture.5.',
#  'Market the API Just as Amazon is an online marketplace for retail, API marketplaces exist for developers to buy and sell other APIs.',
#  'Listing your API can allow you to monetize it.',
#  'What is API testing?API testing strategies are similar to other software testing methodologies.',
#  'The main focus is on validating server responses.',
#  'API testing includes:Making multiple requests to API endpoints for performance testing.',
#  'Writing unit tests for checking business logic and functional correctness.',
#  'Security testing by simulating system attacks.',
#  'How to write API documentation?Writing comprehensive API documentation is part of the API management process.',
#  'API documentation can be auto-generated using tools or written manually.',
#  'Some best practices include:Writing explanations in simple, easy-to-read English.',
#  'Documents generated by tools can become wordy and require editing.',
#  'Using code samples to explain functionality.',
#  'Maintaining the documentation so it is accurate and up-to-date.',
#  'Aiming the writing style at beginnersCovering all the problems the API can solve for the users.',
#  'How to use an API?The steps to implement a new API include:Obtaining an API key.',
#  'This is done by creating a verified account with the API provider.',
#  'Set up an HTTP API client.',
#  'This tool allows you to structure API requests easily using the API keys received.',
#  'If you don’t have an API client, you can try to structure the request yourself in your browser by referring to the API documentation.',
#  'Once you are comfortable with the new API syntax, you can start using it in your code.',
#  'Where can I find new APIs?New web APIs can be found on API marketplaces and API directories.',
#  'API marketplaces are open platforms where anyone can list an API for sale.',
#  'API directories are controlled repositories regulated by the directory owner.',
#  'Expert API designers may assess and test a new API before adding it to their directory.  ',
#  'Some popular API websites include:Rapid API – The largest global API market with over 10,000 public APIs and 1 million active developers on site.',
#  'RapidAPI allows users to test APIs directly on the platform before committing to purchase.',
#  'Public APIs – The platform groups remote APIs into 40 niche categories, making it easier to browse and find the right one to meet your needs.',
#  'APIForThat and APIList – Both these websites have lists of 500+ web APIs, along with in-depth information on how to use them.    ',
#  'What is an API gateway?An API Gateway is an API management tool for enterprise clients that use a broad range of back-end services.',
#  'API gateways typically handle common tasks like user authentication, statistics, and rate management that are applicable across all API calls.',
#  'Amazon API Gateway is a fully managed service that makes it easy for developers to create, publish, maintain, monitor, and secure APIs at any scale.',
#  'It handles all the tasks involved in accepting and processing thousands of concurrent API calls, including traffic management, CORS support, authorization, and access control, throttling, monitoring, and API version management.']

# %%
sent_score = {}

for sent in sent_token:
    for word in sent.split():
        if word.lower() in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent] = word_freq[word]
            else:
                sent_score[sent] += word_freq[word]

sent_score
# Out:
# {'What is an API?APIs are mechanisms that enable two software components to communicate with each other using a set of definitions and protocols.': 0.19767441860465115,
#  'For example, the weather bureau’s software system contains daily weather data.': 0.37209302325581395,
#  'The weather app on your phone “talks” to this system via APIs and shows you daily weather updates on your phone.': 0.3604651162790698,
#  'What does API stand for?API stands for Application Programming Interface.': 0.03488372093023256,
#  'In the context of APIs, the word Application refers to any software with a distinct function.': 0.12790697674418605,
#  'Interface can be thought of as a contract of service between two applications.': 0.09302325581395349,
#  'This contract defines how the two communicate with each other using requests and responses.': 0.1511627906976744,
#  'Their API documentation contains information on how developers are to structure those requests and responses.': 0.33720930232558144,
#  'How do APIs work?API architecture is usually explained in terms of client and server.': 0.2674418604651163,
#  'The application sending the request is called the client, and the application sending the response is called the server.': 0.32558139534883723,
#  'So in the weather example, the bureau’s weather database is the server, and the mobile app is the client.': 0.19767441860465115,
#  'There are four different ways that APIs can work depending on when and why they were created.': 0.13953488372093023,
#  'SOAP APIs These APIs use Simple Object Access Protocol.': 0.12790697674418605,
#  'Client and server exchange messages using XML.': 0.2441860465116279,
#  'This is a less flexible API that was more popular in the past.': 0.06976744186046512,
#  'RPC APIsThese APIs are called Remote Procedure Calls.': 0.03488372093023256,
#  'The client completes a function (or procedure) on the server, and the server sends the output back to the client.': 0.4534883720930232,
#  'Websocket APIsWebsocket API is another modern web API development that uses JSON objects to pass data.': 0.3139534883720931,
#  'A WebSocket API supports two-way communication between client apps and the server.': 0.22093023255813954,
#  'The server can send callback messages to connected clients, making it more efficient than REST API.REST APIsThese are the most popular and flexible APIs found on the web today.': 0.5930232558139534,
#  'The client sends requests to the server as data.': 0.4767441860465117,
#  'The server uses this client input to start internal functions and returns output data back to the client.': 0.7558139534883721,
#  'Let’s look at REST APIs in more detail below.': 0.03488372093023256,
#  'What are REST APIs?REST stands for Representational State Transfer.': 0.023255813953488372,
#  'REST defines a set of functions like GET, PUT, DELETE, etc. that clients can use to access server data.': 0.6162790697674418,
#  'Clients and servers exchange data using HTTP.The main feature of REST API is statelessness.': 0.27906976744186046,
#  'Statelessness means that servers do not save client data between requests.': 0.37209302325581395,
#  'Client requests to the server are similar to URLs you type in your browser to visit a website.': 0.4069767441860465,
#  'The response from the server is plain data, without the typical graphical rendering of a web page.': 0.4418604651162791,
#  'Learn more about Rest APIWhat is web API?A Web API or Web Service API is an application processing interface between a web server and web browser.': 0.8604651162790697,
#  'All web services are APIs but not all APIs are web services.': 0.4069767441860465,
#  'REST API is a special type of Web API that uses the standard architectural style explained above.': 0.16279069767441856,
#  'The different terms around APIs, like Java API or service APIs, exist because historically, APIs were created before the world wide web.': 0.29069767441860467,
#  'Modern web APIs are REST APIs and the terms can be used interchangeably.': 0.20930232558139536,
#  'What are API integrations?API integrations are software components that automatically update data between clients and servers.': 0.37209302325581395,
#  'Some examples of API integrations are when automatic data sync to the cloud from your phone image gallery, or the time and date automatically sync on your laptop when you travel to another time zone.': 0.40697674418604646,
#  'Enterprises can also use them to efficiently automate many system functions.': 0.2558139534883721,
#  'What are the benefits of REST APIs?REST APIs offer four main benefits:1.': 0.10465116279069767,
#  'Integration APIs are used to integrate new applications with existing software systems.': 0.20930232558139536,
#  'This increases development speed because each functionality doesn’t have to be written from scratch.': 0.10465116279069768,
#  'You can use APIs to leverage existing code.2.': 0.16279069767441862,
#  'Innovation Entire industries can change with the arrival of a new app.': 0.10465116279069767,
#  'Businesses need to respond quickly and support the rapid deployment of innovative services.': 0.10465116279069767,
#  'They can do this by making changes at the API level without having to re-write the whole code.3.': 0.11627906976744184,
#  'ExpansionAPIs present a unique opportunity for businesses to meet their clients’ needs across different platforms.': 0.18604651162790697,
#  'For example, maps API allows map information integration via websites, Android,iOS, etc.': 0.12790697674418605,
#  'Any business can give similar access to their internal databases by using free or paid APIs.4.': 0.2674418604651163,
#  'Ease of maintenanceThe API acts as a gateway between two systems.': 0.05813953488372093,
#  'Each system is obliged to make internal changes so that the API is not impacted.': 0.22093023255813954,
#  'This way, any future code changes by one party do not impact the other party.': 0.12790697674418605,
#  'What are the different types of APIs?APIs are classified both according to their architecture and scope of use.': 0.18604651162790697,
#  'We have already explored the main types of API architectures so let’s take a look at the scope of use.': 0.17441860465116277,
#  'Private APIsThese are internal to an enterprise and only used for connecting systems and data within the business.': 0.2906976744186046,
#  'Public APIs These are open to the public and may be used by anyone.': 0.06976744186046512,
#  'There may or not be some authorization and cost associated with these types of APIs.': 0.08139534883720931,
#  'Partner APIs These are only accessible by authorized external developers to aid business-to-business partnerships.': 0.12790697674418605,
#  'Composite APIs These combine two or more different APIs to address complex system requirements or behaviors.': 0.23255813953488372,
#  'What is an API endpoint and why is it important?API endpoints are the final touchpoints in the API communication system.': 0.11627906976744186,
#  'These include server URLs, services, and other specific digital locations from where information is sent and received between systems.': 0.3604651162790698,
#  'API endpoints are critical to enterprises for two main reasons: 1. SecurityAPI endpoints make the system vulnerable to attack.': 0.33720930232558144,
#  'API monitoring is crucial for preventing misuse.2.': 0.06976744186046512,
#  'PerformanceAPI endpoints, especially high traffic ones, can cause bottlenecks and affect system performance.': 0.19767441860465118,
#  'How to secure a REST API?All APIs must be secured through proper authentication and monitoring.': 0.13953488372093023,
#  'The two main ways to secure REST APIs include:1.': 0.1511627906976744,
#  'Authentication tokens These are used to authorize users to make the API call.': 0.10465116279069767,
#  'Authentication tokens check that the users are who they claim to be and that they have access rights for that particular API call.': 0.2325581395348837,
#  'For example, when you log in to your email server, your email client uses authentication tokens for secure access.2.': 0.4534883720930233,
#  'API keys API keys verify the program or application making the API call.': 0.2558139534883721,
#  'They identify the application and ensure it has the access rights required to make the particular API call.': 0.26744186046511625,
#  'API keys are not as secure as tokens but they allow API monitoring in order to gather data on usage.': 0.3837209302325581,
#  'You may have noticed a long string of characters and numbers in your browser URL when you visit different websites.': 0.22093023255813954,
#  'This string is an API key the website uses to make internal API calls.': 0.19767441860465118,
#  'How to create an API?Due diligence and effort are required to build an API that other developers will want to work with and trust.': 0.22093023255813954,
#  'These are the five steps required for high-quality API design:1.': 0.05813953488372093,
#  'Plan the API API specifications, like OpenAPI, provide the blueprint for your API design.': 0.06976744186046512,
#  'It is better to think about different use cases in advance and ensure the API adheres to current API development standards.2.': 0.34883720930232565,
#  'Build the API API designers prototype APIs using boilerplate code.': 0.05813953488372093,
#  'Once the prototype is tested, developers can customize it to internal specifications.3.': 0.18604651162790697,
#  'Test the API  API testing is the same as software testing and must be done to prevent bugs and defects.': 0.2906976744186047,
#  'API testing tools can be used to strength test the API against cyber attacks.4.': 0.19767441860465115,
#  'Document the API  While APIs are self-explanatory, API documentation acts as a guide to improve usability.': 0.11627906976744184,
#  'Well-documented APIs that offer a range of functions and use cases tend to be more popular in a service-oriented architecture.5.': 0.3023255813953488,
#  'Market the API Just as Amazon is an online marketplace for retail, API marketplaces exist for developers to buy and sell other APIs.': 0.18604651162790697,
#  'Listing your API can allow you to monetize it.': 0.03488372093023256,
#  'What is API testing?API testing strategies are similar to other software testing methodologies.': 0.313953488372093,
#  'The main focus is on validating server responses.': 0.2906976744186046,
#  'API testing includes:Making multiple requests to API endpoints for performance testing.': 0.26744186046511625,
#  'Writing unit tests for checking business logic and functional correctness.': 0.11627906976744184,
#  'Security testing by simulating system attacks.': 0.20930232558139533,
#  'How to write API documentation?Writing comprehensive API documentation is part of the API management process.': 0.1627906976744186,
#  'API documentation can be auto-generated using tools or written manually.': 0.12790697674418605,
#  'Some best practices include:Writing explanations in simple, easy-to-read English.': 0.03488372093023256,
#  'Documents generated by tools can become wordy and require editing.': 0.08139534883720931,
#  'Using code samples to explain functionality.': 0.06976744186046512,
#  'Maintaining the documentation so it is accurate and up-to-date.': 0.08139534883720931,
#  'Aiming the writing style at beginnersCovering all the problems the API can solve for the users.': 0.08139534883720931,
#  'How to use an API?The steps to implement a new API include:Obtaining an API key.': 0.2325581395348837,
#  'This is done by creating a verified account with the API provider.': 0.03488372093023256,
#  'Set up an HTTP API client.': 0,
#  'This tool allows you to structure API requests easily using the API keys received.': 0.23255813953488372,
#  'If you don’t have an API client, you can try to structure the request yourself in your browser by referring to the API documentation.': 0.12790697674418605,
#  'Once you are comfortable with the new API syntax, you can start using it in your code.': 0.10465116279069768,
#  'Where can I find new APIs?New web APIs can be found on API marketplaces and API directories.': 0.32558139534883723,
#  'API marketplaces are open platforms where anyone can list an API for sale.': 0.09302325581395349,
#  'API directories are controlled repositories regulated by the directory owner.': 0.08139534883720931,
#  'Expert API designers may assess and test a new API before adding it to their directory.  ': 0.1627906976744186,
#  'Some popular API websites include:Rapid API – The largest global API market with over 10,000 public APIs and 1 million active developers on site.': 0.3255813953488371,
#  'RapidAPI allows users to test APIs directly on the platform before committing to purchase.': 0.1744186046511628,
#  'Public APIs – The platform groups remote APIs into 40 niche categories, making it easier to browse and find the right one to meet your needs.': 0.22093023255813954,
#  'APIForThat and APIList – Both these websites have lists of 500+ web APIs, along with in-depth information on how to use them.    ': 0.4069767441860465,
#  'What is an API gateway?An API Gateway is an API management tool for enterprise clients that use a broad range of back-end services.': 0.3372093023255814,
#  'API gateways typically handle common tasks like user authentication, statistics, and rate management that are applicable across all API calls.': 0.20930232558139533,
#  'Amazon API Gateway is a fully managed service that makes it easy for developers to create, publish, maintain, monitor, and secure APIs at any scale.': 0.2558139534883721,
#  'It handles all the tasks involved in accepting and processing thousands of concurrent API calls, including traffic management, CORS support, authorization, and access control, throttling, monitoring, and API version management.': 0.2209302325581395}

# %%
import heapq

num_sentences = len(sent_token)
top_sent = heapq.nlargest(num_sentences//3, sent_score, key=sent_score.get)

# %%
summary_list = []
for sent in sent_token:
    if sent in top_sent:
        summary_list.append(sent)

summary = "\n".join(summary_list)
print(summary)
# Out:
# For example, the weather bureau’s software system contains daily weather data.
# The weather app on your phone “talks” to this system via APIs and shows you daily weather updates on your phone.
# Their API documentation contains information on how developers are to structure those requests and responses.
# How do APIs work?API architecture is usually explained in terms of client and server.
# The application sending the request is called the client, and the application sending the response is called the server.
# The client completes a function (or procedure) on the server, and the server sends the output back to the client.
# Websocket APIsWebsocket API is another modern web API development that uses JSON objects to pass data.
# The server can send callback messages to connected clients, making it more efficient than REST API.REST APIsThese are the most popular and flexible APIs found on the web today.
# The client sends requests to the server as data.
# The server uses this client input to start internal functions and returns output data back to the client.
# REST defines a set of functions like GET, PUT, DELETE, etc. that clients can use to access server data.
# Clients and servers exchange data using HTTP.The main feature of REST API is statelessness.
# Statelessness means that servers do not save client data between requests.
# Client requests to the server are similar to URLs you type in your browser to visit a website.
# The response from the server is plain data, without the typical graphical rendering of a web page.
# Learn more about Rest APIWhat is web API?A Web API or Web Service API is an application processing interface between a web server and web browser.
# All web services are APIs but not all APIs are web services.
# The different terms around APIs, like Java API or service APIs, exist because historically, APIs were created before the world wide web.
# What are API integrations?API integrations are software components that automatically update data between clients and servers.
# Some examples of API integrations are when automatic data sync to the cloud from your phone image gallery, or the time and date automatically sync on your laptop when you travel to another time zone.
# Enterprises can also use them to efficiently automate many system functions.
# Any business can give similar access to their internal databases by using free or paid APIs.4.
# Private APIsThese are internal to an enterprise and only used for connecting systems and data within the business.
# These include server URLs, services, and other specific digital locations from where information is sent and received between systems.
# API endpoints are critical to enterprises for two main reasons: 1. SecurityAPI endpoints make the system vulnerable to attack.
# For example, when you log in to your email server, your email client uses authentication tokens for secure access.2.
# They identify the application and ensure it has the access rights required to make the particular API call.
# API keys are not as secure as tokens but they allow API monitoring in order to gather data on usage.
# It is better to think about different use cases in advance and ensure the API adheres to current API development standards.2.
# Test the API  API testing is the same as software testing and must be done to prevent bugs and defects.
# Well-documented APIs that offer a range of functions and use cases tend to be more popular in a service-oriented architecture.5.
# What is API testing?API testing strategies are similar to other software testing methodologies.
# The main focus is on validating server responses.
# API testing includes:Making multiple requests to API endpoints for performance testing.
# Where can I find new APIs?New web APIs can be found on API marketplaces and API directories.
# Some popular API websites include:Rapid API – The largest global API market with over 10,000 public APIs and 1 million active developers on site.
# APIForThat and APIList – Both these websites have lists of 500+ web APIs, along with in-depth information on how to use them.
# What is an API gateway?An API Gateway is an API management tool for enterprise clients that use a broad range of back-end services.
